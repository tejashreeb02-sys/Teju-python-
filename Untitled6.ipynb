# %% [markdown]
# <a href="https://colab.research.google.com/github/tejashreeb02-sys/Teju-python-/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter the value of a = "))
b = int(input("Enter the value of b = "))

# Relational Operators
c = a > b
print(c)

d = a < b
print(d)

e = a >= b
print(e)

f = a <= b
print(f)
# Out:
# Enter the value of a = 2
# Enter the value of b = 3
# False
# True
# False
# True
