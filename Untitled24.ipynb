# %% [markdown]
# <a href="https://colab.research.google.com/github/tejashreeb02-sys/Teju-python-/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Membership Operators
list1 = [10, 20, 30, 40]

print(20 in list1)
print(50 not in list1)


# 2. Indexing and Slicing
list1 = [1, 2, 3, 4, 5]

print(list1[0])      # indexing
print(list1[-1])     # negative indexing
print(list1[1:4])    # slicing


# 3. Update, Append, Insert, Remove
list1 = [1, 2, 3]

list1[1] = 10        # update
list1.append(4)      # append
list1.insert(1, 20)  # insert
list1.remove(3)      # delete

print(list1)


# 4. List Operations
list1 = [1, 2]
list2 = [3, 4]

print(list1 + list2)   # concatenation
print(list1 * 2)       # repetition
print(len(list1))      # length
print(max(list1))      # maximum
print(min(list1))      # minimum
# Out:
# True
# True
# 1
# 5
# [2, 3, 4]
# [1, 20, 10, 4]
# [1, 2, 3, 4]
# [1, 2, 1, 2]
# 2
# 2
# 1
