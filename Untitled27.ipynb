# %% [markdown]
# <a href="https://colab.research.google.com/github/tejashreeb02-sys/Teju-python-/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy

import simpy
print("SimPy installed successfully!")

import simpy

def process(env):
    print("Process starts at", env.now)
    yield env.timeout(5)
    print("Process ends at", env.now)

env = simpy.Environment()
env.process(process(env))
env.run()

import simpy

def customer(env):
    print("Customer arrives at", env.now)
    yield env.timeout(3)
    print("Customer served at", env.now)

env = simpy.Environment()
env.process(customer(env))
env.run()

import simpy

def process1(env):
    yield env.timeout(2)
    print("Process 1 completed at", env.now)

def process2(env):
    yield env.timeout(4)
    print("Process 2 completed at", env.now)

env = simpy.Environment()
env.process(process1(env))
env.process(process2(env))
env.run()

wait_times = [2, 4, 3, 1]

average = sum(wait_times) / len(wait_times)

print("Average waiting time:", average)
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.12/dist-packages (4.1.2)
# SimPy installed successfully!
# Process starts at 0
# Process ends at 5
# Customer arrives at 0
# Customer served at 3
# Process 1 completed at 2
# Process 2 completed at 4
# Average waiting time: 2.5
